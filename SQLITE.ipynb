# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Collecting ipython-sql',
#  '  Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)',
#  'Collecting sqlparse',
#  '  Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)',
#  'Collecting prettytable<1',
#  '  Downloading prettytable-0.7.2.zip (28 kB)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\users\\admcn_000\\anaconda3\\lib\\site-packages (from ipython-sql) (7.29.0)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\users\\admcn_000\\anaconda3\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: six in c:\\users\\admcn_000\\anaconda3\\lib\\site-packages (from ipython-sql) (1.16.0)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\users\\admcn_000\\anaconda3\\lib\\site-packages (from ipython-sql) (1.4.22)',
#  'Requirement already satisfied: matplotlib-inline in c:\\users\\admcn_000\\anaconda3\\lib\\site-packages (from ipython>=1.0->ipython-sql) (0.1.2)',
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQL_VBO.db

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# ## MANUEL TABLO OLUŞTURMA İŞLEMLERİ

# %%
# %%sql
# CREATE TABLE yeni_tablo (firstname varchar(20), lastname varchar(20));
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# []

# %%
# %%sql
# INSERT INTO yeni_tablo values("Ali","uzaya git");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM yeni_tablo;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Adem', 'Bakırcı'), ('Ali', 'uzaya git')]

# %%
# %%sql
# INSERT INTO yeni_tablo values("ışık","süte devam");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM yeni_tablo;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Adem', 'Bakırcı'), ('Ali', 'uzaya git'), ('ışık', 'süte devam')]

# %% [markdown]
# ## SELECT

# %%
# %%sql
# SELECT * FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
# ...

# %%
# %%sql
# SELECT * FROM Products LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %sql SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type = "table";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Customers WHERE 1=0;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# []

# %%
# %%sql
# select * from Customers limit 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT CustomerName,Country FROM Customers LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Alfreds Futterkiste', 'Germany'),
#  ('Ana Trujillo Emparedados y helados', 'Mexico'),
#  ('Antonio Moreno Taquería', 'Mexico'),
#  ('Around the Horn', 'UK'),
#  ('Berglunds snabbköp', 'Sweden')]

# %%
# %%sql
# SELECT CustomerName,ContactName,City FROM Customers LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Alfreds Futterkiste', 'Maria Anders', 'Berlin'),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'México D.F.'),
#  ('Antonio Moreno Taquería', 'Antonio Moreno', 'México D.F.'),
#  ('Around the Horn', 'Thomas Hardy', 'London'),
#  ('Berglunds snabbköp', 'Christina Berglund', 'Luleå')]

# %%
# %%sql
# SELECT * FROM products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT Price, Price * 2  FROM products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(18, 36), (19, 38), (10, 20), (22, 44), (21, 42)]

# %%
# %%sql
# SELECT Price * 3,Price * 3 - 25,Price * 4 FROM products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(54, 29, 72), (57, 32, 76), (30, 5, 40), (66, 41, 88), (63, 38, 84)]

# %%
##ALIAS---TAKMA İSİM

# %%
# %%sql
# SELECT Price AS SAF_FİYAT,Price*2 AS İKİ_KATI,Price*3-25 AS YENİ_FİYAT FROM products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(18, 36, 29), (19, 38, 32), (10, 20, 5), (22, 44, 41), (21, 42, 38)]

# %%
#COUNT

# %%
# %%sql
# SELECT COUNT(*) FROM Customers;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(91,)]

# %%
# %%sql
# SELECT COUNT(*) AS SATIR_SAYİSİ FROM Customers;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(91,)]

# %%
#ORDER BY

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT * FROM Products ORDER BY Price LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14)]

# %%
# %%sql
# SELECT ProductName,Unit FROM Products ORDER BY Price LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Konbu', '2 kg box'),
#  ('Filo Mix', '16 - 2 kg boxes'),
#  ('Tunnbröd', '12 - 250 g pkgs.'),
#  ('Aniseed Syrup', '12 - 550 ml bottles'),
#  ("Sir Rodney's Scones", '24 pkgs. x 4 pieces'),
#  ('Longlife Tofu', '5 kg pkg.'),
#  ('Spegesild', '4 - 450 g glasses'),
#  ('Escargots de Bourgogne', '24 pieces'),
#  ('Original Frankfurter grüne Soße', '12 boxes'),
#  ('NuNuCa Nuß-Nougat-Creme', '20 - 450 g glasses')]

# %%
# %%sql
# SELECT * FROM Products ORDER BY Price DESC LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46)]

# %% [markdown]
# ## WHERE

# %%
# %%sql
# SELECT * FROM Customers LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "Germany";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany'),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany'),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (56, 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany'),
#  (63, 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '1307', 'Germany'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE City = "Berlin";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "Germany" AND City = "Münster"
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(79, 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "Germany" OR City = "Münster"
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany'),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany'),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (56, 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany'),
#  (63, 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '1307', 'Germany'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE NOT Country = "Germany";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
# ...

# %%
# %%sql
# SELECT COUNT(*) FROM Customers WHERE Country = 'UK';
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(7,)]

# %%
# %%sql
# SELECT COUNT(*) FROM Customers WHERE Country = 'UK'AND City = 'London' ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(6,)]

# %%
# %%sql
# SELECT * FROM Customers WHERE PostalCode = 5021;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE PostalCode > 5021;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
# %%sql
# SELECT COUNT(*) FROM Customers WHERE PostalCode > 5021;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(49,)]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "USA" AND City = "Seattle";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(89, 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "USA" OR Country = "UK";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
# %%sql
# SELECT * FROM Customers  WHERE Country = "USA" AND (City = "Eugene" OR City = "Elgin") ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers  WHERE Country = "USA" AND PostalCode = "97403" AND  (City = "Eugene" OR City = "Elgin") ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# İN / NOT IN KULLANIMI

# %%
# %%sql
# SELECT * FROM Customers LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerID in (1,3,5,7)  ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
# %%sql
# SELECT * FROM Customers  WHERE Country = "USA" AND PostalCode = "97403" AND  (City = "Eugene" OR City = "Elgin") ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers  WHERE Country = "USA" AND PostalCode in (97403) AND  City in("Eugene","Elgin");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerID NOT IN (1,3,5,7)  ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (12, 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country NOT IN ("UK","USA");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country NOT IN ("UK","USA")AND Country IN("Germany");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany'),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany'),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (56, 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany'),
#  (63, 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '1307', 'Germany'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country NOT IN ("UK","USA") OR Country IN("Germany");
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %% [markdown]
# ## LIKE
# * 'a%' : “a” ile başlayan değerler
# * '%a' : “a” ile biten değerler
# * %or%' : herhangi bir yerinde “or” olan değerler
# * '_r%' : ikinci sirasında “r” olan değerler
# * 'a%%' : “a” ile başlayıp en az 3 karakterden oluşan değerler
# * 'a%o' : “a” ile başlayıp “o” ile biten değerler

# %%
# %%sql
# SELECT * FROM Customers LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE '%or%';
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE 'A%';
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE 'a%';
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE "%te";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (33, 'GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela'),
#  (80, 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '5033', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE "%as";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (58, 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '5033', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE "a%" AND Country LIKE "%i%" ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE "_n%" AND Country LIKE "M%%" ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# ## BETWEEN

# %%
# %%sql
# SELECT * FROM Products LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# SELECT * FROM Products WHERE Price BETWEEN 18 AND 30 LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23),
#  (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21),
#  (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25)]

# %%
# %%sql
# SELECT * FROM Products  WHERE Price BETWEEN 18 AND 30 ORDER BY Price  LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18),
#  (76, 'Lakkalikööri', 23, 1, '500 ml', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19),
#  (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21)]

# %%
# %%sql
# SELECT * FROM Products  WHERE Price BETWEEN 18 AND 30 ORDER BY Price DESC  LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (48, 'Chocolade', 22, 3, '10 pkgs.', 27),
#  (75, 'Rhönbräu Klosterbier', 12, 1, '24 - 0.5 l bottles', 27),
#  (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25),
#  (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23),
#  (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 23),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22)]

# %%
# %%sql
# SELECT * FROM Products  WHERE Price NOT  BETWEEN 18 AND 30 ORDER BY Price DESC  LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46)]

# %%
# %%sql
# SELECT COUNT(*) FROM Products  WHERE Price NOT  BETWEEN 18 AND 30 ORDER BY Price DESC  LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(55,)]

# %%
# %sql SELECT * FROM Products WHERE (Price BETWEEN 18 AND 30) AND (CategoryID NOT IN(1,2,3)) ORDER BY Price;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21),
#  (71, 'Fløtemysost', 15, 4, '10 - 500 g pkgs.', 21),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23),
#  (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 23),
#  (55, 'Pâté chinois', 25, 6, '24 boxes x 2 pies', 24),
#  (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25),
#  (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30)]

# %%
# %sql SELECT * FROM Products WHERE ProductName BETWEEN 'Chais' AND 'Queso Cabrales' ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (13, 'Konbu', 6, 8, '2 kg box', 6),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
#  (22, "Gustaf's Knäckebröd", 9, 5, '24 - 500 g pkgs.', 21),
#  (24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 43),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (26, 'Gumbär Gummibärchen', 11, 3, '100 - 250 g bags', 31),
# ...

# %% [markdown]
# ## AGGREGATION FONKSİYONLARI VE İSTATİKSEL İŞLEMLER

# %%
# %sql SELECT * FROM Products LIMIT 10;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# SELECT MIN(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(6,)]

# %%
# %%sql
# SELECT MAX(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(435,)]

# %%
# %%sql
# SELECT MIN(Price) AS MINIMUM,MAX(Price) AS MAKSIMUM FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(6, 435)]

# %%
# %%sql
# SELECT AVG(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(39.15584415584416,)]

# %%
# %%sql
# SELECT SUM(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(3015,)]

# %%
# %%sql
# SELECT COUNT(*),MAX(Price),MIN(Price),AVG(Price),SUM(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(77, 435, 6, 39.15584415584416, 3015)]

# %%
# %%sql
# SELECT COUNT(Price),MAX(Price),MIN(Price),AVG(Price),SUM(Price) FROM Products;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(77, 435, 6, 39.15584415584416, 3015)]

# %% [markdown]
# ## GROUPBY AND AGGREGATION

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT COUNT(CustomerID),Country FROM Customers GROUP BY Country ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT COUNT(CustomerID) AS MUSTERİ_SAYISI,Country FROM Customers GROUP BY Country ORDER BY  COUNT(CustomerID) DESC ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# %%sql
# SELECT * FROM Products LIMIT 2;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19)]

# %%
# %%sql
# SELECT CategoryID,AVG(Price) AS ORT_FİYAT FROM Products GROUP BY CategoryID;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 42.75),
#  (2, 28.25),
#  (3, 33.76923076923077),
#  (4, 74.9),
#  (5, 23.571428571428573),
#  (6, 55.166666666666664),
#  (7, 32.2),
#  (8, 26.5)]

# %%
# %%sql
# SELECT COUNT(CategoryID),AVG(Price) AS ORT_FİYAT FROM Products GROUP BY CategoryID;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(12, 42.75),
#  (12, 28.25),
#  (13, 33.76923076923077),
#  (10, 74.9),
#  (7, 23.571428571428573),
#  (6, 55.166666666666664),
#  (5, 32.2),
#  (12, 26.5)]

# %%
# %%sql
# SELECT SupplierID, AVG(Price) AS ORT_FİYAT FROM Products GROUP BY SupplierID ORDER BY ORT_FİYAT DESC ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(14, 167.0),
#  (18, 140.5),
#  (12, 48.2),
#  (29, 46.0),
#  (4, 46.0),
#  (8, 44.75),
#  (28, 44.5),
#  (10, 43.0),
#  (26, 40.5),
#  (7, 35.2),
#  (22, 35.0),
#  (15, 33.333333333333336),
#  (19, 33.0),
#  (3, 31.666666666666668),
#  (24, 30.666666666666668),
#  (5, 29.5),
#  (11, 29.333333333333332),
#  (21, 27.5),
#  (20, 26.333333333333332),
#  (2, 25.75),
#  (13, 25.0),
#  (6, 24.0),
#  (25, 20.0),
#  (17, 20.0),
#  (23, 18.0),
#  (1, 15.666666666666666),
#  (16, 15.333333333333334),
#  (9, 15.0),
#  (27, 13.0)]

# %% [markdown]
# ## JOIN İŞLEMLERİ

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE TYPE = "table";
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT CategoryName FROM Categories ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Beverages',),
#  ('Condiments',),
#  ('Confections',),
#  ('Dairy Products',),
#  ('Grains/Cereals',),
#  ('Meat/Poultry',),
#  ('Produce',),
#  ('Seafood',)]

# %%
# %%sql
# SELECT COUNT(CategoryName) FROM Categories ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(8,)]

# %%
# %%sql
# SELECT * FROM Products LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
#LEFT JOIN

# %%
# %%sql
# SELECT * FROM Products LEFT OUTER JOIN Categories ON Products.CategoryID = Categories.CategoryID LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
# %%sql
# SELECT PR.ProductName,CA.CategoryID,CA.CategoryName FROM Products AS PR LEFT OUTER JOIN Categories AS CA ON PR.CategoryID = CA.CategoryID LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %%
# %%sql
# SELECT PR.ProductName,CA.CategoryID,CA.CategoryName FROM Products PR LEFT OUTER JOIN Categories CA ON PR.CategoryID = CA.CategoryID LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %%
# INNER JOIN

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Orders LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# %%sql
# SELECT CU.CustomerName, ORD.OrderID FROM Customers AS CU  INNER JOIN Orders AS ORD ON CU.CustomerID = ORD.CustomerID LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [('Ana Trujillo Emparedados y helados', 10308),
#  ('Antonio Moreno Taquería', 10365),
#  ('Around the Horn', 10355)]

# %%
# %%sql
# SELECT * FROM Customers AS CU  INNER JOIN Orders AS ORD ON CU.CustomerID = ORD.CustomerID LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico', 10308, 2, 7, '18.09.1996', 3),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico', 10365, 3, 3, '27.11.1996', 2),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK', 10355, 4, 6, '15.11.1996', 1)]

# %%
# %%sql
# SELECT COUNT(*) FROM Customers AS CU  INNER JOIN Orders AS ORD ON CU.CustomerID = ORD.CustomerID ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(196,)]

# %%
# %%sql
# SELECT COUNT(*) FROM (SELECT CU.CustomerName, ORD.OrderID FROM Customers AS CU  INNER JOIN Orders AS ORD ON CU.CustomerID = ORD.CustomerID LIMIT 3);
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(3,)]

# %% [markdown]
# ## SQL AND PANDAS DATA FRAME İŞLEMLERİ

# %%
import pandas as pd

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQL_VBO.db

# %%
# %%sql
# SELECT CustomerID AS MUSTERİ_SAYISI, Country FROM Customers  GROUP BY Country  ORDER BY MUSTERİ_SAYISI DESC ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.
# [(91, 'Poland'),
#  (87, 'Finland'),
#  (73, 'Denmark'),
#  (70, 'Norway'),
#  (50, 'Belgium'),
#  (37, 'Ireland'),
#  (33, 'Venezuela'),
#  (32, 'USA'),
#  (28, 'Portugal'),
#  (27, 'Italy'),
#  (20, 'Austria'),
#  (15, 'Brazil'),
#  (14, 'Switzerland'),
#  (12, 'Argentina'),
#  (10, 'Canada'),
#  (8, 'Spain'),
#  (7, 'France'),
#  (5, 'Sweden'),
#  (4, 'UK'),
#  (2, 'Mexico'),
#  (1, 'Germany')]

# %%
df = %sql SELECT CustomerID AS MUSTERİ_SAYISI, Country FROM Customers  GROUP BY Country  ORDER BY MUSTERİ_SAYISI DESC ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///VBO.db
# Done.

# %%
df
# Out:
# [(91, 'Poland'),
#  (87, 'Finland'),
#  (73, 'Denmark'),
#  (70, 'Norway'),
#  (50, 'Belgium'),
#  (37, 'Ireland'),
#  (33, 'Venezuela'),
#  (32, 'USA'),
#  (28, 'Portugal'),
#  (27, 'Italy'),
#  (20, 'Austria'),
#  (15, 'Brazil'),
#  (14, 'Switzerland'),
#  (12, 'Argentina'),
#  (10, 'Canada'),
#  (8, 'Spain'),
#  (7, 'France'),
#  (5, 'Sweden'),
#  (4, 'UK'),
#  (2, 'Mexico'),
#  (1, 'Germany')]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMCN_~1\AppData\Local\Temp/ipykernel_4392/3771845804.py in <module>
# ----> 1 df.info()
#
# AttributeError: 'ResultSet' object has no attribute 'info'

# %%
type(df)
# Out:
# sql.run.ResultSet

# %%
dff = pd.DataFrame(df,columns = ["MUS_SAY","ULKE"])

# %%
dff
# Out:
#     MUS_SAY         ULKE
# 0        91       Poland
# 1        87      Finland
# 2        73      Denmark
# 3        70       Norway
# 4        50      Belgium
# 5        37      Ireland
# 6        33    Venezuela
# 7        32          USA
# 8        28     Portugal
# 9        27        Italy
# 10       20      Austria
# 11       15       Brazil
# 12       14  Switzerland
# 13       12    Argentina
# 14       10       Canada
# 15        8        Spain
# 16        7       France
# 17        5       Sweden
# 18        4           UK
# 19        2       Mexico
# 20        1      Germany

# %%
dff.head()
# Out:
#    MUS_SAY     ULKE
# 0       91   Poland
# 1       87  Finland
# 2       73  Denmark
# 3       70   Norway
# 4       50  Belgium

# %%
dff.tail()
# Out:
#     MUS_SAY     ULKE
# 16        7   France
# 17        5   Sweden
# 18        4       UK
# 19        2   Mexico
# 20        1  Germany

# %%
dff.shape
# Out:
# (21, 2)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MUS_SAY  21 non-null     int64
#  1   ULKE     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
dff.plot.barh(x = "ULKE", y = "MUS_SAY");

# %%
dff.plot.bar();

# %%
import sqlite3

# %%
conn = sqlite3.connect("SQL_VBO.db")

# %%
# ?conn

# %%
c = conn.cursor()

# %%
# read sql

# %%
ab = pd.read_sql("""SELECT COUNT(CustomerID) AS MUS_SAY,
Country 
FROM Customers 
GROUP BY Country;""",conn)

# %%
ab
# Out:
#     MUS_SAY      Country
# 0         3    Argentina
# 1         2      Austria
# 2         2      Belgium
# 3         9       Brazil
# 4         3       Canada
# 5         2      Denmark
# 6         2      Finland
# 7        11       France
# 8        11      Germany
# 9         1      Ireland
# 10        3        Italy
# 11        5       Mexico
# 12        1       Norway
# 13        1       Poland
# 14        2     Portugal
# 15        5        Spain
# 16        2       Sweden
# 17        2  Switzerland
# 18        7           UK
# 19       13          USA
# 20        4    Venezuela

# %%
type(ab)
# Out:
# pandas.core.frame.DataFrame

# %%
#conn.close()

# %%
c.execute("SELECT CustomerName FROM Customers LIMIT 5; ")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("SELECT CustomerName FROM Customers LIMIT 5; "):
    print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)

# %%
type(row)
# Out:
# tuple

# %%
list = []
for row in c.execute("SELECT CustomerName FROM Customers LIMIT 5; "):
    list.append(row)
print(list)
# Out:
# [('Alfreds Futterkiste',), ('Ana Trujillo Emparedados y helados',), ('Antonio Moreno Taquería',), ('Around the Horn',), ('Berglunds snabbköp',)]

# %%
type(list)
# Out:
# list

# %% [markdown]
# ## SQL ALIŞTIRMALAR

# %%
# %load_ext sql

# %%
# %sql sqlite:///SQL_VBO.db

# %%
# %%sql
# SELECT * FROM CUstOmers LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %% [markdown]
# ## 1. Orders tablosunda kaç müşteri oldugunu bulunuz.
# 2. Orders tablosunda kaç tane eşsiz müşteri olduğunu bulunuz.
# 3. Customers tablosunda hangi ülkeden kaçar tane müşteri olduğunu bulunuz.
# 4. Müşterilerin ülkesi Brazil ya da USA olanlarını bulunuz.
# 5. Önce ülkeye sonra şehre göre group by işlemi yapıp bu kırılımda müşteri sayısını bulunuz.
# SQL ALIŞTIRMALARI II
# 6. Müşterileri adreslerinin herhangi bir yerinde "da" ifadesi geçen tüm adresleri bulunuz.
# 7. Germany-Berlin'de yaşayan müşteri/müşterilerin isimleri nelerdir?
# 8. Canada'da yaşayıp isimlerinde "in" ifadesi geçen müşteri/müşterileri bulunuz.
# 9. Fiyatı 40 TL ile 90 TL arasında olan ürünlerin isimleri ve fiyatları nelerdir?
# 10. Fiyatı 30 TL'den büyük olan ürünlerin isimlerini, fiyatlarini ve fiyatlarinin karesini bulunuz ve tüm değişkenlerin isimlendirmelerini aşağıdaki şekilde yapınız:
# urun ismi, urun_fiyati, ürün_fiyatinin_karesi
#
# SQL ALIŞTIRMALARI III
# 11. Products tablosundaki CategoryID’lerin yani kategorilerin isimleri nelerdir?
# 12. beverages ürün kategorisindeki ürünlerin fiyat ortalaması nedir?
# 13. USA'de yaşayan müşterilerin kazandırdığı toplam kazancı bulunuz.
# 14. Products tablosundaki CategoryID'lerin isimlerini bulunuz ve sonrasında kategori başına ortalama ürün fiyatını gösteriniz.
# 15. Çalışanları (EmployeeID) isimleri ile birlikte yaptıkları toplam satışlara göre sıralayınız.
# SQL ALIŞTIRMALARI IV
# 16. Germany'dan verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?
# 17. Almanya ya da USA'den verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?
# 18. Haziran Temmuz Ağustos aylarında verilen siparişlerin ortalama fiyatı nedir?
# 19. Müşterilerin 1997 yılına ait siparişlerinin maksimum miktarlarını bulup müşterilerin isimleri ile birlikte büyükten küçüğe sıralayınız.
# 20. Sipariş yılı 1997 olan siparişleri alan çalışanları sipariş alma sayılarına göre sıralayınız.

# %%
# %%sql
# SELECT * FROM Orders  LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# 1

# %%
# %%sql
# SELECT COUNT(*) FROM Orders  LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(196,)]

# %%
#2

# %%
# %%sql
# SELECT COUNT(DISTINCT CustomerID) AS UNIQUE_CustomerID FROM Orders  LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(74,)]

# %%
##3.Customers tablosunda hangi ülkeden kaçar tane müşteri olduğunu bulunuz

# %%
# %%sql
# SELECT * FROM Customers LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')]

# %%
# %%sql
# SELECT CustomerID AS MUS_SAYISI,Country FROM Customers GROUP BY Country ORDER BY MUS_SAYISI DESC ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(91, 'Poland'),
#  (87, 'Finland'),
#  (73, 'Denmark'),
#  (70, 'Norway'),
#  (50, 'Belgium'),
#  (37, 'Ireland'),
#  (33, 'Venezuela'),
#  (32, 'USA'),
#  (28, 'Portugal'),
#  (27, 'Italy'),
#  (20, 'Austria'),
#  (15, 'Brazil'),
#  (14, 'Switzerland'),
#  (12, 'Argentina'),
#  (10, 'Canada'),
#  (8, 'Spain'),
#  (7, 'France'),
#  (5, 'Sweden'),
#  (4, 'UK'),
#  (2, 'Mexico'),
#  (1, 'Germany')]

# %%
## 4 Müşterilerin ülkesi Brazil ya da USA olanlarını bulunuz.

# %%
# %%sql
# SELECT * FROM Customers WHERE Country IN("Brazil","USA") ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "Brazil" OR Country = "USA" ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
## 5-Önce ülkeye sonra şehre göre group by işlemi yapıp bu kırılımda müşteri sayısını bulunuz.

# %%
# %%sql
# SELECT COUNT(CustomerID),Country  FROM Customers GROUP BY Country ORDER BY CustomerID DESC  ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(1, 'Poland'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (1, 'Norway'),
#  (2, 'Belgium'),
#  (1, 'Ireland'),
#  (4, 'Venezuela'),
#  (13, 'USA'),
#  (2, 'Portugal'),
#  (3, 'Italy'),
#  (2, 'Austria'),
#  (9, 'Brazil'),
#  (2, 'Switzerland'),
#  (3, 'Argentina'),
#  (3, 'Canada'),
#  (5, 'Spain'),
#  (11, 'France'),
#  (2, 'Sweden'),
#  (7, 'UK'),
#  (5, 'Mexico'),
#  (11, 'Germany')]

# %%
# %%sql
# SELECT COUNT(CustomerID),City  FROM Customers GROUP BY City ORDER BY CustomerID DESC  ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(1, 'Walla'),
#  (1, 'Helsinki'),
#  (1, 'Seattle'),
#  (1, 'Resende'),
#  (1, 'Oulu'),
#  (1, 'Stuttgart'),
#  (1, 'Reims'),
#  (1, 'Lyon'),
#  (1, 'Århus'),
#  (1, 'Kirkland'),
#  (1, 'Münster'),
#  (1, 'Butte'),
#  (1, 'Charleroi'),
#  (1, 'Lander'),
#  (1, 'København'),
#  (1, 'Boise'),
#  (1, 'Stavern'),
#  (1, 'Genève'),
#  (1, 'Reggio Emilia'),
#  (1, 'Albuquerque'),
#  (1, 'Cunewalde'),
#  (1, 'Salzburg'),
#  (2, 'Paris'),
#  (1, 'Köln'),
#  (1, 'Anchorage'),
#  (1, 'Leipzig'),
#  (1, 'Montréal'),
#  (1, 'Bruxelles'),
#  (1, 'Bergamo'),
#  (2, 'Portland'),
#  (1, 'I. de Margarita'),
#  (1, 'Barquisimeto'),
#  (1, 'San Francisco'),
#  (1, 'Frankfurt a.M.'),
#  (1, 'Walla Walla'),
#  (1, 'Vancouver'),
#  (1, 'Toulouse'),
#  (1, 'Versailles'),
#  (1, 'Brandenburg'),
#  (1, 'Cowes'),
#  (1, 'Cork'),
#  (1, 'Elgin'),
#  (1, 'San Cristóbal'),
#  (3, 'Rio de Janeiro'),
#  (1, 'Caracas'),
#  (1, 'Eugene'),
#  (1, 'Campinas'),
# ...

# %%
# %%sql
# SELECT COUNT(CustomerID), Country, City  FROM Customers GROUP BY Country,City ORDER BY CustomerID DESC  ;
# Out:
#  * sqlite:///SQL_VBO.db
#    sqlite:///vbo.db
# Done.
# [(1, 'Poland', 'Walla'),
#  (1, 'Finland', 'Helsinki'),
#  (1, 'USA', 'Seattle'),
#  (1, 'Brazil', 'Resende'),
#  (1, 'Finland', 'Oulu'),
#  (1, 'Germany', 'Stuttgart'),
#  (1, 'France', 'Reims'),
#  (1, 'France', 'Lyon'),
#  (1, 'Denmark', 'Århus'),
#  (1, 'USA', 'Kirkland'),
#  (1, 'Germany', 'Münster'),
#  (1, 'USA', 'Butte'),
#  (1, 'Belgium', 'Charleroi'),
#  (1, 'USA', 'Lander'),
#  (1, 'Denmark', 'København'),
#  (1, 'USA', 'Boise'),
#  (1, 'Norway', 'Stavern'),
#  (1, 'Switzerland', 'Genève'),
#  (1, 'Italy', 'Reggio Emilia'),
#  (1, 'USA', 'Albuquerque'),
#  (1, 'Germany', 'Cunewalde'),
#  (1, 'Austria', 'Salzburg'),
#  (2, 'France', 'Paris'),
#  (1, 'Germany', 'Köln'),
#  (1, 'USA', 'Anchorage'),
#  (1, 'Germany', 'Leipzig'),
#  (1, 'Canada', 'Montréal'),
#  (1, 'Belgium', 'Bruxelles'),
#  (1, 'Italy', 'Bergamo'),
#  (2, 'USA', 'Portland'),
#  (1, 'Venezuela', 'I. de Margarita'),
#  (1, 'Venezuela', 'Barquisimeto'),
# ...

# %%
## 6- Müşterileri adreslerinin herhangi bir yerinde "da" ifadesi geçen tüm adresleri bulunuz.

# %%
# %load_ext sql

# %%
# %sql sqlite:///SQL_VBO.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Address LIKE "%da%" ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
# ...

# %%
## 7. Germany-Berlin'de yaşayan müşteri/müşterilerin isimleri nelerdir?

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE Country IN("Germany") AND City IN("Berlin");
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Alfreds Futterkiste',)]

# %%
## 8. Canada'da yaşayıp isimlerinde "in" ifadesi geçen müşteri/müşterileri bulunuz.

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE "%in%" AND Country IN("Canada") ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(42, 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')]

# %%
## 9. Fiyatı 40 TL ile 90 TL arasında olan ürünlerin isimleri ve fiyatları nelerdir?

# %%
# %%sql
# SELECT name FROM sqlite_master where  type = "table";
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT ProductName,Price FROM Products WHERE Price > 40 AND Price < 90 ORDER BY Price DESC;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [("Sir Rodney's Marmalade", 81),
#  ('Carnarvon Tigers', 62),
#  ('Raclette Courdavault', 55),
#  ('Manjimup Dried Apples', 53),
#  ('Tarte au sucre', 49),
#  ('Ipoh Coffee', 46),
#  ('Rössle Sauerkraut', 45),
#  ('Scottish Longbreads', 45),
#  ('Genen Shouyu', 43),
#  ('Teatime Chocolate Biscuits', 43),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Ravioli Angelo', 43),
#  ("Sirop d'érable", 43),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43)]

# %%
# %%sql
# SELECT ProductName,Price FROM Products WHERE Price BETWEEN  40 AND 90 ORDER BY Price DESC;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [("Sir Rodney's Marmalade", 81),
#  ('Carnarvon Tigers', 62),
#  ('Raclette Courdavault', 55),
#  ('Manjimup Dried Apples', 53),
#  ('Tarte au sucre', 49),
#  ('Ipoh Coffee', 46),
#  ('Rössle Sauerkraut', 45),
#  ('Scottish Longbreads', 45),
#  ('Genen Shouyu', 43),
#  ('Teatime Chocolate Biscuits', 43),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Ravioli Angelo', 43),
#  ("Sirop d'érable", 43),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43),
#  ('Northwoods Cranberry Sauce', 40)]

# %%
## 10. Fiyatı 30 TL'den büyük olan ürünlerin isimlerini, fiyatlarini ve fiyatlarinin karesini bulunuz
#ve tüm değişkenlerin isimlendirmelerini aşağıdaki şekilde yapınız:
#urun ismi, urun_fiyati, ürün_fiyatinin_karesi

# %%
# %%sql
# SELECT ProductName AS urun_ismi , Price AS urun_fiyati, Price*Price AS  ürün_fiyatinin_karesi  FROM Products WHERE Price > 30 ORDER BY Price DESC;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Gorgonzola Telino', 435, 189225),
#  ('Côte de Blaye', 263, 69169),
#  ('Thüringer Rostbratwurst', 123, 15129),
#  ('Mishi Kobe Niku', 97, 9409),
#  ("Sir Rodney's Marmalade", 81, 6561),
#  ('Carnarvon Tigers', 62, 3844),
#  ('Raclette Courdavault', 55, 3025),
#  ('Manjimup Dried Apples', 53, 2809),
#  ('Tarte au sucre', 49, 2401),
#  ('Ipoh Coffee', 46, 2116),
#  ('Rössle Sauerkraut', 45, 2025),
#  ('Scottish Longbreads', 45, 2025),
#  ('Genen Shouyu', 43, 1849),
#  ('Teatime Chocolate Biscuits', 43, 1849),
#  ('Guaraná Fantástica', 43, 1849),
#  ('Schoggi Schokolade', 43, 1849),
#  ('Geitost', 43, 1849),
#  ('Boston Crab Meat', 43, 1849),
#  ('Røgede sild', 43, 1849),
#  ('Zaanse koeken', 43, 1849),
#  ('Ravioli Angelo', 43, 1849),
#  ("Sirop d'érable", 43, 1849),
#  ('Vegie-spread', 43, 1849),
#  ('Louisiana Fiery Hot Pepper Sauce', 43, 1849),
#  ('Northwoods Cranberry Sauce', 40, 1600),
#  ('Alice Mutton', 39, 1521),
# ...

# %%
## 11. Products tablosundaki CategoryID’lerin yani kategorilerin isimleri nelerdir?

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQL_VBO.db

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type ="table";
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Products LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 3;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT P.CategoryID,C.CategoryName FROM Categories AS C INNER JOIN Products AS P ON C.CategoryID = P.CategoryID LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages')]

# %%
# %%sql
# SELECT P.CategoryID,C.CategoryName FROM Categories AS C LEFT OUTER JOIN Products AS P ON C.CategoryID = P.CategoryID LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages'),
#  (1, 'Beverages')]

# %%
## 12. beverages ürün kategorisindeki ürünlerin fiyat ortalaması nedir?

# %%
# %%sql
# SELECT AVG(Price) FROM Categories AS C LEFT OUTER JOIN Products AS P ON C.CategoryID = P.CategoryID
#               WHERE CategoryName IN("Beverages");
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(42.75,)]

# %%
# %%sql
# SELECT * FROM Categories AS C LEFT OUTER JOIN Products AS P ON C.CategoryID = P.CategoryID
#               WHERE CategoryName IN("Beverages");
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 24, 'Guaraná Fantástica', 10, 1, '12 - 355 ml cans', 43),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18),
#  (1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales', 43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46),
# ...

# %%
## 13. USA'de yaşayan müşterilerin kazandırdığı toplam kazancı bulunuz.

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type = "table";
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Orders LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# %%sql
# SELECT SUM(P.Price) FROM
# OrderDetails OD INNER JOIN Orders O ON OD.OrderID = O.OrderID
# INNER JOIN  Customers C ON O.CustomerID = C.CustomerID
# INNER JOIN Products P ON OD.ProductID = P.ProductID
# WHERE Country IN("USA")
#
# LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(3762,)]

# %%
# %%sql
# SELECT SUM(P.Price) FROM
# OrderDetails OD LEFT JOIN Orders O ON OD.OrderID = O.OrderID
# LEFT JOIN  Customers C ON O.CustomerID = C.CustomerID
# LEFT JOIN Products P ON OD.ProductID = P.ProductID
# WHERE Country IN("USA")
#
# LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(3762,)]

# %%
# %%sql
# SELECT SUM(Price) FROM
# Products p
# INNER JOIN OrderDetails od ON p.ProductID = od.ProductID
# INNER JOIN Orders o ON od.OrderID = o.OrderID
# INNER JOIN Customers c ON o.CustomerID = c.CustomerID
# WHERE Country IN("USA")
# LIMIT 5;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(3762,)]

# %%
# %%sql
# SELECT * FROM OrderDetails LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 10248, 11, 12), (2, 10248, 42, 10), (3, 10248, 72, 5)]

# %%
# %%sql
# SELECT * FROM Products LIMIT 3 ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# SELECT * FROM
# Products p
# INNER JOIN OrderDetails od ON p.ProductID = od.ProductID
# INNER JOIN Orders o ON od.OrderID = o.OrderID
# INNER JOIN Customers c ON o.CustomerID = c.CustomerID
# WHERE Country IN("USA")
# LIMIT 1;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23, 339, 10375, 14, 15, 10375, 36, 3, '6.12.1996', 2, 36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
## 14. Products tablosundaki CategoryID'lerin isimlerini bulunuz ve sonrasında kategori başına ortalama ürün fiyatını gösteriniz

# %%
# %%sql
# SELECT * FROM Products LIMIT 1;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18)]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 1;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales')]

# %%
# %%sql
# SELECT CategoryName,AVG(Price) ORT_FİYAT FROM Products p
# INNER JOIN Categories c ON p.CategoryID = c.CategoryID
# GROUP BY CategoryName
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Beverages', 42.75),
#  ('Condiments', 28.25),
#  ('Confections', 33.76923076923077),
#  ('Dairy Products', 74.9),
#  ('Grains/Cereals', 23.571428571428573),
#  ('Meat/Poultry', 55.166666666666664),
#  ('Produce', 32.2),
#  ('Seafood', 26.5)]

# %%
##15. Çalışanları (EmployeeID) isimleri ile birlikte yaptıkları toplam satışlara göre sıralayınız.¶

# %%
# %%sql
# SELECT e.EmployeeID,LastName,FirstName,SUM(Price*Quantity) TOP_SATIŞ FROM Employees e
# INNER JOIN Orders o ON e.EmployeeID = o.EmployeeID
# LEFT JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# GROUP BY e.EmployeeID
# ORDER BY TOP_SATIŞ DESC
# LIMIT 20;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(4, 'Peacock', 'Margaret', 156706),
#  (1, 'Davolio', 'Nancy', 106896),
#  (6, 'Suyama', 'Michael', 88934),
#  (3, 'Leverling', 'Janet', 68204),
#  (5, 'Buchanan', 'Steven', 60293),
#  (7, 'King', 'Robert', 54416),
#  (8, 'Callahan', 'Laura', 43225),
#  (2, 'Fuller', 'Andrew', 41294),
#  (9, 'Dodsworth', 'Anne', 17656)]

# %%
## 16. Germany'dan verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?

# %%
# %%sql
# SELECT CategoryName,AVG(Price) FROM Orders o
# LEFT JOIN Customers c ON o.CustomerID = c.CustomerID
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# INNER JOIN Categories ca ON p.CategoryID = ca.CategoryID
# WHERE Country IN("Germany")
# GROUP BY CategoryName
# ORDER BY AVG(Price) DESC
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Dairy Products', 151.64705882352942),
#  ('Confections', 40.0),
#  ('Condiments', 34.0),
#  ('Produce', 30.75),
#  ('Meat/Poultry', 30.2),
#  ('Seafood', 27.09090909090909),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Beverages', 20.5)]

# %%
##17. Almanya ya da USA'den verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?¶

# %%
# %%sql
# SELECT CategoryName,AVG(Price) FROM Orders o
# LEFT JOIN Customers c ON o.CustomerID = c.CustomerID
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# INNER JOIN Categories ca ON p.CategoryID = ca.CategoryID
# WHERE Country IN("Germany","USA")
# GROUP BY CategoryName
# ORDER BY AVG(Price) DESC
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Dairy Products', 131.75862068965517),
#  ('Meat/Poultry', 46.75),
#  ('Confections', 39.92307692307692),
#  ('Condiments', 34.72727272727273),
#  ('Beverages', 29.88888888888889),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' OR cu.Country = 'USA' GROUP BY CategoryName;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %%
## 18. Haziran Temmuz Ağustos aylarında verilen siparişlerin ortalama fiyatı nedir?

# %%
# %%sql
# SELECT  AVG(Price) FROM Orders o
#
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
#
# WHERE OrderDate LIKE "%.08.%" OR OrderDate LIKE  "%.07.%" OR OrderDate LIKE "%.06.%"
#
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(42.4765625,)]

# %%
# %%sql
# SELECT AVG(Products.Price)
# FROM Products
# LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(39.71891891891892,)]

# %%
# %%sql
# SELECT AVG(Price),o.OrderID FROM Orders o
# LEFT JOIN Customers c ON o.CustomerID = c.CustomerID
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# INNER JOIN Categories ca ON p.CategoryID = ca.CategoryID
# WHERE OrderDate LIKE "%.08.%" OR OrderDate LIKE  "%.07.%" OR OrderDate LIKE "%.06.%"
# GROUP BY o.OrderID
# ORDER BY AVG(Price) DESC
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(183.33333333333334, 10272),
#  (157.66666666666666, 10253),
#  (114.0, 10273),
#  (81.0, 10292),
#  (78.5, 10268),
#  (52.666666666666664, 10252),
#  (49.0, 10275),
#  (47.0, 10277),
#  (44.25, 10290),
#  (43.75, 10293),
#  (43.0, 10271),
#  (39.666666666666664, 10250),
#  (39.0, 10279),
#  (38.666666666666664, 10267),
#  (38.5, 10283),
#  (38.5, 10269),
#  (38.0, 10266),
#  (38.0, 10249),
#  (35.666666666666664, 10251),
#  (34.666666666666664, 10281),
#  (34.0, 10282),
#  (33.5, 10286),
#  (33.0, 10278),
#  (32.8, 10294),
#  (32.5, 10270),
#  (32.5, 10260),
#  (31.333333333333332, 10280),
#  (31.0, 10285),
#  (30.5, 10288),
#  (29.666666666666668, 10262),
#  (27.5, 10284),
#  (27.5, 10274),
#  (27.5, 10255),
#  (27.0, 10265),
#  (26.0, 10291),
#  (25.666666666666668, 10254),
#  (24.666666666666668, 10257),
#  (24.0, 10258),
#  (23.75, 10263),
#  (23.0, 10248),
#  (22.5, 10256),
#  (21.5, 10289),
#  (21.0, 10264),
#  (18.5, 10276),
# ...

# %%
## 19. Müşterilerin 1997 yılına ait siparişlerinin maksimum miktarlarını bulup müşterilerin
#isimleri ile birlikte büyükten küçüğe sıralayınız.

# %%
# %%sql
# SELECT CustomerName, MAX(Price) FROM Orders o
# LEFT JOIN Customers c ON o.CustomerID = c.CustomerID
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# INNER JOIN Categories ca ON p.CategoryID = ca.CategoryID
# WHERE OrderDate LIKE "%.1997%"
# GROUP BY CustomerName
# ORDER BY MAX(Price) DESC
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Gourmet Lanchonetes', 435),
#  ('Simons bistro', 263),
#  ('Mère Paillarde', 263),
#  ('Save-a-lot Markets', 123),
#  ('Eastern Connection', 123),
#  ('Wellington Importadora', 97),
#  ('Ernst Handel', 55),
#  ('Bottom-Dollar Marketse', 55),
#  ("La maison d'Asie", 49),
#  ('Folies gourmandes', 49),
#  ('Reggiani Caseifici', 45),
#  ('Queen Cozinha', 45),
#  ('Wartian Herkku', 43),
#  ('Toms Spezialitäten', 43),
#  ('Rattlesnake Canyon Grocery', 43),
#  ('Que Delícia', 43),
#  ('QUICK-Stop', 43),
#  ('Old World Delicatessen', 43),
#  ('Hungry Owl All-Night Grocers', 43),
#  ('Hungry Coyote Import Store', 43),
#  ('Familia Arquibaldo', 43),
#  ('Princesa Isabel Vinhoss', 38),
#  ('Galería del gastrónomo', 38),
#  ('Blondel père et fils', 38),
#  ('Richter Supermarkt', 36),
#  ('Ottilies Käseladen', 36),
#  ('Consolidated Holdings', 34),
#  ('Split Rail Beer & Ale', 31),
#  ('Magazzini Alimentari Riuniti', 31),
#  ('Franchi S.p.A.', 31),
# ...

# %%
# %%sql
# SELECT CustomerName, MAX(Price) maks
# FROM Products
# LEFT JOIN OrderDetails on Products.ProductID = OrderDetails.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# LEFT JOIN Customers on Customers.CustomerID = Orders.CustomerID
# WHERE OrderDate like '%1997%'
# GROUP BY CustomerName ORDER BY maks DESC;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Gourmet Lanchonetes', 435),
#  ('Simons bistro', 263),
#  ('Mère Paillarde', 263),
#  ('Save-a-lot Markets', 123),
#  ('Eastern Connection', 123),
#  ('Wellington Importadora', 97),
#  ('Ernst Handel', 55),
#  ('Bottom-Dollar Marketse', 55),
#  ("La maison d'Asie", 49),
#  ('Folies gourmandes', 49),
#  ('Reggiani Caseifici', 45),
#  ('Queen Cozinha', 45),
#  ('Wartian Herkku', 43),
#  ('Toms Spezialitäten', 43),
#  ('Rattlesnake Canyon Grocery', 43),
#  ('Que Delícia', 43),
#  ('QUICK-Stop', 43),
#  ('Old World Delicatessen', 43),
#  ('Hungry Owl All-Night Grocers', 43),
#  ('Hungry Coyote Import Store', 43),
#  ('Familia Arquibaldo', 43),
#  ('Princesa Isabel Vinhoss', 38),
#  ('Galería del gastrónomo', 38),
#  ('Blondel père et fils', 38),
#  ('Richter Supermarkt', 36),
#  ('Ottilies Käseladen', 36),
#  ('Consolidated Holdings', 34),
#  ('Split Rail Beer & Ale', 31),
#  ('Magazzini Alimentari Riuniti', 31),
#  ('Franchi S.p.A.', 31),
# ...

# %%
## 20. Sipariş yılı 1997 olan siparişleri alan çalışanları sipariş alma sayılarına göre sıralayınız.

# %%
# %%sql
# SELECT FirstName,LastName,COUNT(*) FROM Orders o
# LEFT JOIN Customers c ON o.CustomerID = c.CustomerID
# INNER JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON od.ProductID = p.ProductID
# INNER JOIN Categories ca ON p.CategoryID = ca.CategoryID
# LEFT JOIN Employees e ON o.EmployeeID = e.EmployeeID
# WHERE OrderDate LIKE "%.1997%"
# GROUP BY LastName
# ORDER BY SUM(Quantity) DESC
#
# ;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [('Margaret', 'Peacock', 26),
#  ('Janet', 'Leverling', 31),
#  ('Laura', 'Callahan', 19),
#  ('Nancy', 'Davolio', 8),
#  ('Robert', 'King', 9),
#  ('Andrew', 'Fuller', 9),
#  ('Michael', 'Suyama', 8),
#  ('Anne', 'Dodsworth', 3)]

# %%
# %%sql
# SELECT COUNT(*) n, em.FirstName
# FROM Orders
# LEFT JOIN Employees em on Orders.EmployeeID = em.EmployeeID
# WHERE OrderDate like '%1997%'
# GROUP BY em.FirstName
# ORDER by n DESC;
# Out:
#  * sqlite:///SQL_VBO.db
# Done.
# [(13, 'Janet'),
#  (9, 'Margaret'),
#  (8, 'Laura'),
#  (4, 'Andrew'),
#  (3, 'Robert'),
#  (3, 'Nancy'),
#  (3, 'Michael'),
#  (1, 'Anne')]
